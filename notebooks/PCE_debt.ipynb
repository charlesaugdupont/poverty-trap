# %%
import numpy as np
import pickle
import os
import sys
import itertools as it

import matplotlib.pyplot as plt
from SALib.sample import saltelli

import tqdm
import time
import contextlib

sys.path.append('./GDMaps_PCE/')
from DimensionReduction import Grassmann
from DimensionReduction import DiffusionMaps
from GDMaps_PCE_GSA import *

from UQpy.distributions import Normal, Uniform, JointIndependent

import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid
plt.rcParams.update(plt.rcParamsDefault)
plt.rcParams.update({"font.size" : 15,
                     "figure.dpi" : 100, 
                     "grid.alpha" : 0.3, 
                     "axes.grid": True, 
                     "axes.axisbelow" : True,
                     "figure.figsize":(8,6),
                     "mathtext.fontset":"cm",
                     "xtick.labelsize": 14,
                     "ytick.labelsize": 14,
                     "axes.labelsize": 16, 
                     "legend.fontsize": 13.5})

plt.rc("text", usetex=False)
plt.rc("font", family="serif")

# %%
def PCE_LAR_model_selection(x, g, n_params, dist_obj, max_degree):
  
    n_dcoords = g.shape[1]
    
    # construct total-degree polynomial basis
    polynomial_basis = TotalDegreeBasis(dist_obj, max_degree)

    least_squares = LeastSquareRegression()
    pce = PolynomialChaosExpansion(polynomial_basis=polynomial_basis, regression_method=least_squares)

    xx_train, xx_test, \
        gg_train, gg_test = train_test_split(x, g, train_size=2 / 3, random_state=1)

    error_pceLAR = np.zeros((n_dcoords))
    LOO_pceLAR   = np.zeros((n_dcoords))
    pceLAR_fo_si = np.zeros((n_params, n_dcoords))
    pceLAR_to_si = np.zeros((n_params, n_dcoords))

    for i in range(n_dcoords):        
        pce.fit(xx_train, gg_train[:, i])
        # Lars model selection
        print('Size of the full set of PCE basis:', polynomial_basis.polynomials_number)

        target_error = 1
        CheckOverfitting = True
        pceLAR = polynomial_chaos.regressions.LeastAngleRegression.model_selection(pce, 
                                                                                   target_error, 
                                                                                   CheckOverfitting)

        print('Size of the LAR PCE basis:', pceLAR.polynomial_basis.polynomials_number)

        error_pceLAR[i] = ErrorEstimation(surr_object=pceLAR).validation(xx_test, gg_test[:, i])           
        LOO_pceLAR[i]   = pceLAR.leaveoneout_error()

        print('Leave-one-out cross validation on ED:', pceLAR.leaveoneout_error())

        pceLAR_sensitivity = PceSensitivity(pceLAR)
        pceLAR_sensitivity.run()

        LAR_sobol_first = pceLAR_sensitivity.first_order_indices
        LAR_sobol_total = pceLAR_sensitivity.total_order_indices

        pceLAR_fo_si[:, i] = LAR_sobol_first.T
        pceLAR_to_si[:, i] = LAR_sobol_total.T
        
    return (error_pceLAR, LOO_pceLAR, pceLAR_fo_si, pceLAR_to_si)

# %%
# problem definition
PROBLEM = {
    "num_vars" : 6,
    "names"    : ["theta",
                  "gain_right",
                  "saving_prop",
                  "prob_left",
                  "alpha",
                  "assistance"],
    "bounds"   : [[0.01, 0.20],
                  [1.70, 8.00],
                  [0.70, 0.80],
                  [0.30, 0.45],
                  [2.00, 12.0],
                  [0.05, 0.30]]
}
# generate Saltelli samples
NUM_SAMPLES = 1024
X = saltelli.sample(PROBLEM, NUM_SAMPLES, calc_second_order=False)
print(f'Problem bounds: {PROBLEM["bounds"]}')


pdf1 = Uniform(loc=0.01, scale=0.19) 
pdf2 = Uniform(loc=1.70, scale=6.30)  
pdf3 = Uniform(loc=0.70, scale=0.10)  
pdf4 = Uniform(loc=0.30, scale=0.15)  
pdf5 = Uniform(loc=2.00, scale=10.0)  
pdf6 = Uniform(loc=0.05, scale=0.25)
margs = [pdf1, pdf2, pdf3, pdf4, pdf5, pdf6]
joint = JointIndependent(marginals=margs)

for pdf in margs:
    print(pdf.parameters["loc"], pdf.parameters["loc"]+pdf.parameters["scale"])
# Out:
# Problem bounds: [[0.01, 0.2], [1.7, 8.0], [0.7, 0.8], [0.3, 0.45], [2.0, 12.0], [0.05, 0.3]]
# 0.01 0.2
# 1.7 8.0
# 0.7 0.7999999999999999
# 0.3 0.44999999999999996
# 2.0 12.0
# 0.05 0.3

# %% [markdown]
# # Micro

# %%
micro_files = sorted([f for f in os.listdir("GDMAPS_results/") if "micro" in f])

d_coords = []
for f in micro_files:
    with open("GDMAPS_results/" + f, "rb") as f:
        _, _, _, g_diff_runs, _, _ = pickle.load(f)
    d_coords.append(g_diff_runs[0])
    
n_params = X.shape[1]
n_dcoords = d_coords[0].shape[1]
n_runs = len(d_coords)
n_params, n_dcoords, n_runs

# %%
s_max = [6, 12]

LAR_fo_si = np.zeros((n_runs, len(s_max), n_params, n_dcoords))
LAR_to_si = np.zeros((n_runs, len(s_max), n_params, n_dcoords))
LAR_error = np.zeros((n_runs, len(s_max), n_dcoords))
LAR_LOO   = np.zeros((n_runs, len(s_max), n_dcoords))

for run in range(n_runs):
    print("Run:", run)
    g = d_coords[run]

    for i, s in enumerate(s_max):
        print("Max polynomial degree:", s)

        start_time = time.time()
        LAR_result = PCE_LAR_model_selection(x=x, 
                                             g=g, 
                                             n_params=n_params, 
                                             dist_obj=joint, 
                                             max_degree=s)
        
        LAR_fo_si[run, i] = LAR_result[2]
        LAR_to_si[run, i] = LAR_result[3]
        LAR_error[run, i] = LAR_result[0]
        LAR_LOO[run, i]   = LAR_result[1]
        
        print("--- PCE-LAR took %s seconds ---" % (time.time() - start_time))
        
        RES = [LAR_fo_si, LAR_to_si, LAR_error, LAR_LOO]
        with open("PCE_LAR_RESULTS_micro.pickle", "wb") as f:
            pickle.dump(RES, f)
# Out:
# Run: 0
# Max polynomial degree: 6
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 286
# Leave-one-out cross validation on ED: 0.0030073
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 254
# Leave-one-out cross validation on ED: 0.0147998
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 198
# Leave-one-out cross validation on ED: 0.0087234
# --- PCE-LAR took 153.49882173538208 seconds ---
# Max polynomial degree: 12
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 332
# Leave-one-out cross validation on ED: 0.0021251
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 274
# Leave-one-out cross validation on ED: 0.0093433
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 318
# Leave-one-out cross validation on ED: 0.0056339
# --- PCE-LAR took 586.7554819583893 seconds ---
# Run: 1
# Max polynomial degree: 6
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 210
# Leave-one-out cross validation on ED: 0.004418
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 272
# Leave-one-out cross validation on ED: 0.0077751
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 189
# Leave-one-out cross validation on ED: 0.0143221
# --- PCE-LAR took 131.33240294456482 seconds ---
# Max polynomial degree: 12
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 130
# Leave-one-out cross validation on ED: 0.0038117
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 330
# Leave-one-out cross validation on ED: 0.0055059
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 196
# Leave-one-out cross validation on ED: 0.0091023
# --- PCE-LAR took 456.88058495521545 seconds ---
# Run: 2
# Max polynomial degree: 6
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 213
# Leave-one-out cross validation on ED: 0.0031569
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 254
# Leave-one-out cross validation on ED: 0.0096567
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 212
# Leave-one-out cross validation on ED: 0.0081475
# --- PCE-LAR took 128.5914168357849 seconds ---
# Max polynomial degree: 12
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 204
# Leave-one-out cross validation on ED: 0.0025448
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 399
# Leave-one-out cross validation on ED: 0.0059657
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 225
# Leave-one-out cross validation on ED: 0.0058924
# --- PCE-LAR took 542.4750783443451 seconds ---
# Run: 3
# Max polynomial degree: 6
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 192
# Leave-one-out cross validation on ED: 0.0043134
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 240
# Leave-one-out cross validation on ED: 0.0105743
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 278
# Leave-one-out cross validation on ED: 0.0068855
# --- PCE-LAR took 154.40400981903076 seconds ---
# Max polynomial degree: 12
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 316
# Leave-one-out cross validation on ED: 0.0029514
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 372
# Leave-one-out cross validation on ED: 0.0075426
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 329
# Leave-one-out cross validation on ED: 0.0055509
# --- PCE-LAR took 612.1925830841064 seconds ---
# Run: 4
# Max polynomial degree: 6
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 227
# Leave-one-out cross validation on ED: 0.0043654
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 261
# Leave-one-out cross validation on ED: 0.0147928
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 230
# Leave-one-out cross validation on ED: 0.0110925
# --- PCE-LAR took 188.44856691360474 seconds ---
# Max polynomial degree: 12
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 84
# Leave-one-out cross validation on ED: 0.005352
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 137
# Leave-one-out cross validation on ED: 0.0149
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 168
# Leave-one-out cross validation on ED: 0.0117288
# --- PCE-LAR took 349.50129294395447 seconds ---
# Run: 5
# Max polynomial degree: 6
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 192
# Leave-one-out cross validation on ED: 0.0039268
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 256
# Leave-one-out cross validation on ED: 0.0404891
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 254
# Leave-one-out cross validation on ED: 0.032263
# --- PCE-LAR took 157.45075631141663 seconds ---
# Max polynomial degree: 12
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 345
# Leave-one-out cross validation on ED: 0.0029742
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 211
# Leave-one-out cross validation on ED: 0.0290221
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 459
# Leave-one-out cross validation on ED: 0.0106622
# --- PCE-LAR took 665.4042806625366 seconds ---
# Run: 6
# Max polynomial degree: 6
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 250
# Leave-one-out cross validation on ED: 0.0043207
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 251
# Leave-one-out cross validation on ED: 0.01078
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 332
# Leave-one-out cross validation on ED: 0.0096446
# --- PCE-LAR took 224.33683276176453 seconds ---
# Max polynomial degree: 12
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 437
# Leave-one-out cross validation on ED: 0.0028819
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 329
# Leave-one-out cross validation on ED: 0.0071327
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 382
# Leave-one-out cross validation on ED: 0.0074047
# --- PCE-LAR took 794.7840061187744 seconds ---
# Run: 7
# Max polynomial degree: 6
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 197
# Leave-one-out cross validation on ED: 0.0043515
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 229
# Leave-one-out cross validation on ED: 0.0124163
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 225
# Leave-one-out cross validation on ED: 0.0071794
# --- PCE-LAR took 135.66617918014526 seconds ---
# Max polynomial degree: 12
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 271
# Leave-one-out cross validation on ED: 0.0032798
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 356
# Leave-one-out cross validation on ED: 0.0085214
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 340
# Leave-one-out cross validation on ED: 0.0047875
# --- PCE-LAR took 602.3498721122742 seconds ---
# Run: 8
# Max polynomial degree: 6
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 235
# Leave-one-out cross validation on ED: 0.0045058
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 265
# Leave-one-out cross validation on ED: 0.0126507
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 272
# Leave-one-out cross validation on ED: 0.0063227
# --- PCE-LAR took 180.1975827217102 seconds ---
# Max polynomial degree: 12
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 320
# Leave-one-out cross validation on ED: 0.0029792
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 285
# Leave-one-out cross validation on ED: 0.0080861
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 248
# Leave-one-out cross validation on ED: 0.0048637
# --- PCE-LAR took 571.701003074646 seconds ---
# Run: 9
# Max polynomial degree: 6
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 266
# Leave-one-out cross validation on ED: 0.0033326
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 268
# Leave-one-out cross validation on ED: 0.0103903
# Size of the full set of PCE basis: 924
# Size of the LAR PCE basis: 291
# Leave-one-out cross validation on ED: 0.008641
# --- PCE-LAR took 239.08093690872192 seconds ---
# Max polynomial degree: 12
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 300
# Leave-one-out cross validation on ED: 0.0027156
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 447
# Leave-one-out cross validation on ED: 0.0071768
# Size of the full set of PCE basis: 18564
# Size of the LAR PCE basis: 450
# Leave-one-out cross validation on ED: 0.0062522
# --- PCE-LAR took 875.0059571266174 seconds ---

# %% [markdown]
# # Global

# %%
global_files = sorted([f for f in os.listdir("../GDMaps_results_debt/") if "macro" in f])

d_coords = []
for f in global_files:
    with open("../GDMaps_results_debt/" + f, "rb") as f:
        _, _, _, g_diff_runs, _, _ = pickle.load(f)
    d_coords.append(g_diff_runs[0])
    
n_params = X.shape[1]
n_dcoords = d_coords[0].shape[1]
n_runs = len(d_coords)
n_params, n_dcoords, n_runs
# Out:
# (6, 3, 20)

# %%
# s_max = [6, 12]

s_max = [18]

LAR_fo_si = np.zeros((n_runs, len(s_max), n_params, n_dcoords))
LAR_to_si = np.zeros((n_runs, len(s_max), n_params, n_dcoords))
LAR_error = np.zeros((n_runs, len(s_max), n_dcoords))
LAR_LOO   = np.zeros((n_runs, len(s_max), n_dcoords))

for run in range(n_runs):
    print("Run:", run)
    g = d_coords[run]

    for i, s in enumerate(s_max):
        print("Max polynomial degree:", s)

        start_time = time.time()
        LAR_result = PCE_LAR_model_selection(x=X, 
                                             g=g, 
                                             n_params=n_params, 
                                             dist_obj=joint, 
                                             max_degree=s)
        
        LAR_fo_si[run, i] = LAR_result[2]
        LAR_to_si[run, i] = LAR_result[3]
        LAR_error[run, i] = LAR_result[0]
        LAR_LOO[run, i]   = LAR_result[1]
        
        print("--- PCE-LAR took %s seconds ---" % (time.time() - start_time))
        
        RES = [LAR_fo_si, LAR_to_si, LAR_error, LAR_LOO]
        with open("PCE_LAR_RESULTS_macro_18_debt.pickle", "wb") as f:
            pickle.dump(RES, f)
# Out:
# Run: 0
# Max polynomial degree: 18
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 176
# Leave-one-out cross validation on ED: 0.2144019
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 965
# Leave-one-out cross validation on ED: 0.5349251
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 955
# Leave-one-out cross validation on ED: 0.5074404
# --- PCE-LAR took 4298.566088914871 seconds ---
# Run: 1
# Max polynomial degree: 18
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 218
# Leave-one-out cross validation on ED: 0.2073835
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 966
# Leave-one-out cross validation on ED: 0.5650272
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 961
# Leave-one-out cross validation on ED: 0.5103189
# --- PCE-LAR took 4541.451691150665 seconds ---
# Run: 2
# Max polynomial degree: 18
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 151
# Leave-one-out cross validation on ED: 0.2122898
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 968
# Leave-one-out cross validation on ED: 0.5501592
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 927
# Leave-one-out cross validation on ED: 0.5033095
# --- PCE-LAR took 4562.557749032974 seconds ---
# Run: 3
# Max polynomial degree: 18
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 158
# Leave-one-out cross validation on ED: 0.1987437
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 970
# Leave-one-out cross validation on ED: 0.5237426
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 942
# Leave-one-out cross validation on ED: 0.5140027
# --- PCE-LAR took 4479.173441886902 seconds ---
# Run: 4
# Max polynomial degree: 18
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 248
# Leave-one-out cross validation on ED: 0.1662201
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 977
# Leave-one-out cross validation on ED: 0.5398602
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 949
# Leave-one-out cross validation on ED: 0.5307663
# --- PCE-LAR took 4505.168893098831 seconds ---
# Run: 5
# Max polynomial degree: 18
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 259
# Leave-one-out cross validation on ED: 0.1894817
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 965
# Leave-one-out cross validation on ED: 0.5537948
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 973
# Leave-one-out cross validation on ED: 0.4951066
# --- PCE-LAR took 4546.509759187698 seconds ---
# Run: 6
# Max polynomial degree: 18
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 199
# Leave-one-out cross validation on ED: 0.223581
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 965
# Leave-one-out cross validation on ED: 0.5539176
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 966
# Leave-one-out cross validation on ED: 0.4969295
# --- PCE-LAR took 4390.433530807495 seconds ---
# Run: 7
# Max polynomial degree: 18
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 136
# Leave-one-out cross validation on ED: 0.2147889
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 948
# Leave-one-out cross validation on ED: 0.4778141
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 967
# Leave-one-out cross validation on ED: 0.4917311
# --- PCE-LAR took 4199.042186021805 seconds ---
# Run: 8
# Max polynomial degree: 18
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 167
# Leave-one-out cross validation on ED: 0.1908673
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 953
# Leave-one-out cross validation on ED: 0.5740605
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 954
# Leave-one-out cross validation on ED: 0.5113267
# --- PCE-LAR took 4334.708069801331 seconds ---
# Run: 9
# Max polynomial degree: 18
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 177
# Leave-one-out cross validation on ED: 0.2122258
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 887
# Leave-one-out cross validation on ED: 0.5860802
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 924
# Leave-one-out cross validation on ED: 0.5132671
# --- PCE-LAR took 4316.983380794525 seconds ---
# Run: 10
# Max polynomial degree: 18
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 170
# Leave-one-out cross validation on ED: 0.2260352
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 945
# Leave-one-out cross validation on ED: 0.531028
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 956
# Leave-one-out cross validation on ED: 0.5597275
# --- PCE-LAR took 4812.073771238327 seconds ---
# Run: 11
# Max polynomial degree: 18
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 193
# Leave-one-out cross validation on ED: 0.1838229
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 895
# Leave-one-out cross validation on ED: 0.5353136
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 965
# Leave-one-out cross validation on ED: 0.5123891
# --- PCE-LAR took 4462.52387714386 seconds ---
# Run: 12
# Max polynomial degree: 18
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 135
# Leave-one-out cross validation on ED: 0.1938892
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 920
# Leave-one-out cross validation on ED: 0.5274199
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 922
# Leave-one-out cross validation on ED: 0.4858314
# --- PCE-LAR took 3929.9264466762543 seconds ---
# Run: 13
# Max polynomial degree: 18
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 187
# Leave-one-out cross validation on ED: 0.1970861
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 969
# Leave-one-out cross validation on ED: 0.5346259
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 913
# Leave-one-out cross validation on ED: 0.5201749
# --- PCE-LAR took 4026.9559030532837 seconds ---
# Run: 14
# Max polynomial degree: 18
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 208
# Leave-one-out cross validation on ED: 0.1998319
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 961
# Leave-one-out cross validation on ED: 0.5526923
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 908
# Leave-one-out cross validation on ED: 0.5582213
# --- PCE-LAR took 4005.5228831768036 seconds ---
# Run: 15
# Max polynomial degree: 18
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 155
# Leave-one-out cross validation on ED: 0.2491089
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 916
# Leave-one-out cross validation on ED: 0.5306729
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 938
# Leave-one-out cross validation on ED: 0.49527
# --- PCE-LAR took 3970.0194528102875 seconds ---
# Run: 16
# Max polynomial degree: 18
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 224
# Leave-one-out cross validation on ED: 0.2219452
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 811
# Leave-one-out cross validation on ED: 0.5193754
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 943
# Leave-one-out cross validation on ED: 0.5330666
# --- PCE-LAR took 3821.786554813385 seconds ---
# Run: 17
# Max polynomial degree: 18
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 260
# Leave-one-out cross validation on ED: 0.1852523
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 886
# Leave-one-out cross validation on ED: 0.5086588
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 925
# Leave-one-out cross validation on ED: 0.5736441
# --- PCE-LAR took 4068.238809108734 seconds ---
# Run: 18
# Max polynomial degree: 18
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 210
# Leave-one-out cross validation on ED: 0.2086217
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 955
# Leave-one-out cross validation on ED: 0.5183632
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 966
# Leave-one-out cross validation on ED: 0.504169
# --- PCE-LAR took 4138.3739902973175 seconds ---
# Run: 19
# Max polynomial degree: 18
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 169
# Leave-one-out cross validation on ED: 0.2319067
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 963
# Leave-one-out cross validation on ED: 0.5470215
# Size of the full set of PCE basis: 134596
# Size of the LAR PCE basis: 964
# Leave-one-out cross validation on ED: 0.4830764
# --- PCE-LAR took 4536.275194168091 seconds ---

# %% [markdown]
# # Global Results

# %%
s_max = [18]

with open("PCE_LAR_RESULTS_macro_18_debt.pickle", 'rb') as f:
    [LAR_fo_si, LAR_to_si, LAR_error, LAR_LOO] = pickle.load(f)
    
param_names = ["theta", "gain_right", "saving_prop", "prob_left", "alpha", "assistance"]
n_dcoords = 3

fig, axs = plt.subplots(3, 1, figsize=(6, 12), constrained_layout=True)

# ERROR
for d in range(n_dcoords):
    axs[0].scatter(s_max, LAR_LOO.mean(axis=0)[:, d], label=r"$\theta_{d}$".format(d=d+1))
    axs[0].errorbar(s_max, LAR_LOO.mean(axis=0)[:, d],
                      LAR_LOO.std(axis=0, ddof=1)[:, d],
                      linestyle='--', marker='o', capsize=4)
    axs[0].legend()
for i in range(3):
    axs[0].set(ylabel=r'Validation error', xlabel=r'$s_{\max}$')
    axs[0].set(ylabel=r'LOO error', xlabel=r'$s_{\max}$')

# First order si
for i, param in enumerate(param_names):
    axs[1].scatter([1,2,3],LAR_fo_si.mean(axis=0)[0][i], label=param_names[i])    
    axs[1].errorbar([1,2,3], LAR_fo_si.mean(axis=0)[0][i],
                      LAR_fo_si.std(axis=0, ddof=1)[0][i],
                      linestyle='--', marker='o', capsize=4)
    axs[1].set_xticks([1,2,3], labels=[rf"$\theta_{i}$" for i in range(1,4)], fontsize=16)
    axs[1].set_title(r"$S_i$ $(s_{max}=18)$")
    axs[1].legend()

# Total order si
for i, param in enumerate(param_names):
    axs[2].scatter([1,2,3],LAR_to_si.mean(axis=0)[0][i], label=param_names[i])    
    axs[2].errorbar([1,2,3], LAR_to_si.mean(axis=0)[0][i],
                      LAR_to_si.std(axis=0, ddof=1)[0][i],
                      linestyle='--', marker='o', capsize=4)
    axs[2].set_xticks([1,2,3], labels=[rf"$\theta_{i}$" for i in range(1,4)], fontsize=16)
    axs[2].set_title(r"$S_{T_i}$ $(s_{max}=18)$")
    axs[2].legend()
    
plt.show()

# %% [markdown]
# # Combine $S_i, S_{T_i}$ for micro, meso, macro

# %%
fig, axs = plt.subplots(3, 2, figsize=(12,12))
param_names = [r"$COST$", r"$G_{upper}$", r"$\beta$", r"$\ell$", r"$\sigma$", r"$\lambda$"]
theta_labels = [r"First $\theta$", r"Second $\theta$", r"Third $\theta$"]
colors = [u'#1f77b4', u'#ff7f0e', u'#2ca02c', u'#d62728', u'#9467bd', u'#e377c2']


# MICRO
with open("../data/PCE_LAR_RESULTS_micro.pickle", 'rb') as f:
    [LAR_fo_si, LAR_to_si, LAR_error, LAR_LOO] = pickle.load(f)
# First order si
for i, param in enumerate(param_names):
    axs[0][0].scatter([1,2,3],LAR_fo_si.mean(axis=0)[1][i], label=param_names[i], color=colors[i])    
    axs[0][0].errorbar([1,2,3], LAR_fo_si.mean(axis=0)[1][i],
                      LAR_fo_si.std(axis=0, ddof=1)[1][i],
                      linestyle='--', marker='o', capsize=4, color=colors[i])
    axs[0][0].set_xticks([1,2,3], labels=theta_labels, fontsize=16)
    axs[0][0].set_title(r"$S_i$ at Micro Level", fontsize=20)
    axs[0][0].set_ylim(-0.05,0.95)
# Total order si
for i, param in enumerate(param_names):
    axs[0][1].scatter([1,2,3],LAR_to_si.mean(axis=0)[1][i], label=param_names[i], color=colors[i])    
    axs[0][1].errorbar([1,2,3], LAR_to_si.mean(axis=0)[1][i],
                      LAR_to_si.std(axis=0, ddof=1)[1][i],
                      linestyle='--', marker='o', capsize=4, color=colors[i])
    axs[0][1].set_xticks([1,2,3], labels=theta_labels, fontsize=16)
    axs[0][1].set_title(r"$S_{T_i}$ at Micro Level", fontsize=20)
    axs[0][1].set_ylim(-0.05,0.95)
    
# MESO
with open("../data/PCE_LAR_RESULTS_meso.pickle", 'rb') as f:
    [LAR_fo_si, LAR_to_si, LAR_error, LAR_LOO] = pickle.load(f)
# First order si
for i, param in enumerate(param_names):
    axs[1][0].scatter([1,2,3],LAR_fo_si.mean(axis=0)[1][i], label=param_names[i], color=colors[i])    
    axs[1][0].errorbar([1,2,3], LAR_fo_si.mean(axis=0)[1][i],
                      LAR_fo_si.std(axis=0, ddof=1)[1][i],
                      linestyle='--', marker='o', capsize=4, color=colors[i])
    axs[1][0].set_xticks([1,2,3], labels=theta_labels, fontsize=16)
    axs[1][0].set_title(r"$S_i$ at Meso Level", fontsize=20)
    axs[1][0].set_ylim(-0.05,0.95)
# Total order si
for i, param in enumerate(param_names):
    axs[1][1].scatter([1,2,3],LAR_to_si.mean(axis=0)[1][i], label=param_names[i], color=colors[i])    
    axs[1][1].errorbar([1,2,3], LAR_to_si.mean(axis=0)[1][i],
                      LAR_to_si.std(axis=0, ddof=1)[1][i],
                      linestyle='--', marker='o', capsize=4, color=colors[i])
    axs[1][1].set_xticks([1,2,3], labels=theta_labels, fontsize=16)
    axs[1][1].set_title(r"$S_{T_i}$ at Meso Level", fontsize=20)
    axs[1][1].set_ylim(-0.05,0.95)

# MACRO
with open("../data/PCE_LAR_RESULTS_global.pickle", 'rb') as f:
    [LAR_fo_si, LAR_to_si, LAR_error, LAR_LOO] = pickle.load(f)
# First order si
for i, param in enumerate(param_names):
    axs[2][0].scatter([1,2,3],LAR_fo_si.mean(axis=0)[1][i], label=param_names[i], color=colors[i])    
    axs[2][0].errorbar([1,2,3], LAR_fo_si.mean(axis=0)[1][i],
                      LAR_fo_si.std(axis=0, ddof=1)[1][i],
                      linestyle='--', marker='o', capsize=4, color=colors[i])
    axs[2][0].set_xticks([1,2,3], labels=theta_labels, fontsize=16)
    axs[2][0].set_title(r"$S_i$ at Macro Level", fontsize=20)
    axs[2][0].set_ylim(-0.05,0.95)
# Total order si
for i, param in enumerate(param_names):
    axs[2][1].scatter([1,2,3],LAR_to_si.mean(axis=0)[1][i], label=param_names[i], color=colors[i])    
    axs[2][1].errorbar([1,2,3], LAR_to_si.mean(axis=0)[1][i],
                      LAR_to_si.std(axis=0, ddof=1)[1][i],
                      linestyle='--', marker='o', capsize=4, color=colors[i])
    axs[2][1].set_xticks([1,2,3], labels=theta_labels, fontsize=16)
    axs[2][1].set_title(r"$S_{T_i}$ at Macro Level", fontsize=20)
    axs[2][1].set_ylim(-0.05,0.95)

    
handles, labels = axs[0][0].get_legend_handles_labels()
legend = fig.legend(handles, labels, title="Parameter", ncol=6, 
                    bbox_to_anchor=(0.835,1.1), fontsize=16, shadow=True)
legend.get_title().set_fontsize('20') #legend 'Title' fontsize
fig.tight_layout()
plt.savefig("../figures/sensitivity_indices.pdf", bbox_inches="tight")
plt.show()
